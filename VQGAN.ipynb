# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaheemJ/CelestAI/blob/main/VQGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# === Cell 1: Install dependencies ===
# !pip install datasets pyarrow
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (18.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from datasets import load_dataset

# Hyperparameters (improved)
IMG_SIZE        = 64
BATCH_SIZE      = 32
NUM_IMAGES      = 500
LATENT_DIM      = 256
NUM_EMBEDDINGS  = 1024         # Increased from 512
COMMITMENT_COST = 0.5          # Increased from 0.25
EPOCHS          = 200          # Increased from 100

# %%
# === Cell 3: Load & buffer the first NUM_IMAGES from LEGACYSURVEY ===
# (we’ll load into RAM since NUM_IMAGES is small)
ds_stream = load_dataset("MultimodalUniverse/legacysurvey", split="train", streaming=True)
it = iter(ds_stream)
raw = [next(it) for _ in range(NUM_IMAGES)]
# Out:
# Resolving data files:   0%|          | 0/165 [00:00<?, ?it/s]

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Define IMG_SIZE if not already defined
IMG_SIZE = 64

def preprocess(example):
    flux = np.array(example["image"]["flux"])  # shape (bands, H, W)
    gray = np.mean(flux, axis=0)               # average bands
    gray = np.clip(gray, 0, 1)
    img = Image.fromarray((gray * 255).astype(np.uint8))
    img = img.resize((IMG_SIZE, IMG_SIZE))
    arr = np.array(img, dtype=np.float32) / 255.0
    return np.expand_dims(arr, -1)             # (IMG_SIZE,IMG_SIZE,1)

# Build NumPy array
train_images = np.stack([preprocess(x) for x in raw], axis=0)
print("Dataset shape:", train_images.shape)   # (NUM_IMAGES,64,64,1)

# Display a grid of images
def display_image_grid(images, grid_size=5, title="Processed Images"):
    """Display a grid of images from the dataset"""
    plt.figure(figsize=(10, 10))
    plt.suptitle(title, fontsize=16)

    # Display up to grid_size × grid_size images
    num_images = min(grid_size * grid_size, len(images))

    for i in range(num_images):
        plt.subplot(grid_size, grid_size, i + 1)
        # Remove the channel dimension and display the image
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.axis('off')
        plt.title(f"Image {i+1}")

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# Display a grid of 25 images (5×5)
display_image_grid(train_images)
# Out:
# Dataset shape: (500, 64, 64, 1)

# %%
# === Cell 5: Create tf.data pipeline ===
dataset = (
    tf.data.Dataset
      .from_tensor_slices(train_images)
      .shuffle(1000)
      .batch(BATCH_SIZE)
      .prefetch(tf.data.AUTOTUNE)
)

# %%
# === Cell 6: Vector Quantizer layer ===
class VectorQuantizer(layers.Layer):
    def __init__(self, num_embeddings, embedding_dim, commitment_cost, **kwargs):
        super().__init__(**kwargs)
        self.num_embeddings  = num_embeddings
        self.embedding_dim   = embedding_dim
        self.commitment_cost = commitment_cost
        # codebook: [D, K]
        w_init = tf.random_uniform_initializer()
        self.embeddings = tf.Variable(
            initial_value=w_init(shape=(embedding_dim, num_embeddings)),
            trainable=True, name="embeddings"
        )

    def call(self, inputs):
        # inputs: [B, H, W, D]
        flat = tf.reshape(inputs, [-1, self.embedding_dim])  # [BHW, D]
        # compute L2 distance to embeddings
        distances = (
            tf.reduce_sum(flat**2, axis=1, keepdims=True)
            - 2 * tf.matmul(flat, self.embeddings)
            + tf.reduce_sum(self.embeddings**2, axis=0, keepdims=True)
        )  # [BHW, K]
        indices = tf.argmin(distances, axis=1)               # [BHW]
        one_hot = tf.one_hot(indices, self.num_embeddings)   # [BHW, K]
        quantized = tf.matmul(one_hot, tf.transpose(self.embeddings))  # [BHW, D]
        quantized = tf.reshape(quantized, tf.shape(inputs))            # [B,H,W,D]

        # losses
        e_latent_loss = tf.reduce_mean((tf.stop_gradient(quantized) - inputs)**2)
        q_latent_loss = tf.reduce_mean((quantized - tf.stop_gradient(inputs))**2)
        loss = q_latent_loss + self.commitment_cost * e_latent_loss
        self.add_loss(loss)

        # straight‑through estimator
        return inputs + tf.stop_gradient(quantized - inputs)

# %%
# Cell 7 (fixed): Build Encoder & Decoder for VQGAN

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def build_encoder():
    inp = keras.Input((IMG_SIZE, IMG_SIZE, 1))
    x = layers.Conv2D(128, 4, strides=2, padding="same", activation="relu")(inp)
    x = layers.Conv2D(256, 4, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2D(LATENT_DIM, 1, padding="same")(x)   # No activation on final bottleneck
    return keras.Model(inputs=inp, outputs=x, name="encoder")

def build_decoder():
    # Decoder input corresponds to the encoder's downsampled feature map
    downscale = IMG_SIZE // 4  # two stride-2 convs reduce H/W by factor of 4
    inp_shape = (downscale, downscale, LATENT_DIM)
    inp = keras.Input(shape=inp_shape)
    x = layers.Conv2DTranspose(256, 4, strides=2, padding="same", activation="relu")(inp)
    x = layers.Conv2DTranspose(128, 4, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2DTranspose(1,   3, strides=1, padding="same", activation="sigmoid")(x)
    return keras.Model(inputs=inp, outputs=x, name="decoder")

# Instantiate
encoder = build_encoder()
decoder = build_decoder()

# Summaries (optional)
encoder.summary()
decoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 128)    │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 256)    │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 256)    │        65,792 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 592,512 (2.26 MB)
#  Trainable params: 592,512 (2.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 32, 32, 256)    │     1,048,832 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 64, 64, 128)    │       524,416 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 64, 64, 1)      │         1,153 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,574,401 (6.01 MB)
#  Trainable params: 1,574,401 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# === Cell 8: Build Discriminator ===
def build_discriminator():
    inp = keras.Input((IMG_SIZE,IMG_SIZE,1))
    x = layers.Conv2D(64, 4, strides=2, padding="same", activation="leaky_relu")(inp)
    x = layers.Conv2D(128,4, strides=2, padding="same", activation="leaky_relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1)(x)
    return keras.Model(inp, x, name="discriminator")

discriminator = build_discriminator()

# %%
# === Cell 9: VQGAN as a custom Model ===
class VQGAN(keras.Model):
    def __init__(self, encoder, quantizer, decoder, discriminator, **kwargs):
        super().__init__(**kwargs)
        self.encoder       = encoder
        self.quantizer     = quantizer
        self.decoder       = decoder
        self.discriminator = discriminator
        self.l1_loss       = keras.losses.MeanAbsoluteError()
        self.bce_loss      = keras.losses.BinaryCrossentropy(from_logits=True)

    def compile(self, g_optimizer, d_optimizer):
        super().compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer

    def train_step(self, real):
        # 1) Generator (encoder→quantizer→decoder)
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            # encode → quantize → decode
            z_e = self.encoder(real)
            z_q = self.quantizer(z_e)
            recon = self.decoder(z_q)

            # recon loss with increased weight
            recon_weight = 10.0  # Higher weight on reconstruction quality
            recon_loss = self.l1_loss(real, recon)

            # adversarial loss for generator with decreased weight
            adv_weight = 0.1  # Lower weight on adversarial loss initially
            fake_logits = self.discriminator(recon)
            adv_loss_g = self.bce_loss(tf.ones_like(fake_logits), fake_logits)

            g_loss = recon_weight * recon_loss + adv_weight * adv_loss_g + sum(self.quantizer.losses)

            # discriminator loss remains the same
            real_logits = self.discriminator(real)
            adv_loss_d = (
                self.bce_loss(tf.ones_like(real_logits), real_logits) +
                self.bce_loss(tf.zeros_like(fake_logits), fake_logits)
            )

        # gradients
        grads_g = gen_tape.gradient(g_loss, self.encoder.trainable_weights
                                       + self.quantizer.trainable_weights
                                       + self.decoder.trainable_weights)
        grads_d = disc_tape.gradient(adv_loss_d, self.discriminator.trainable_weights)

        # apply
        self.g_optimizer.apply_gradients(zip(grads_g, self.encoder.trainable_weights
                                                + self.quantizer.trainable_weights
                                                + self.decoder.trainable_weights))
        self.d_optimizer.apply_gradients(zip(grads_d, self.discriminator.trainable_weights))

        return {"g_loss": g_loss, "d_loss": adv_loss_d, "recon_loss": recon_loss}

# %%
# === Cell 10: Instantiate & compile VQGAN ===
quantizer = VectorQuantizer(NUM_EMBEDDINGS, LATENT_DIM, COMMITMENT_COST)
vqgan = VQGAN(encoder, quantizer, decoder, discriminator)

vqgan.compile(
    g_optimizer = keras.optimizers.Adam(1e-4),
    d_optimizer = keras.optimizers.Adam(4e-4)
)

# %%
# === Cell 11: Training loop with results printed every 10 epochs ===
import tensorflow as tf

# Create a custom callback to print results every 10 epochs
class PrintEveryNEpochs(tf.keras.callbacks.Callback):
    def __init__(self, n=5):
        super(PrintEveryNEpochs, self).__init__()
        self.n = n

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.n == 0:
            print(f"\n=== Results after epoch {epoch + 1} ===")
            for metric_name, metric_value in logs.items():
                print(f"{metric_name}: {metric_value:.4f}")
            print("="*30)

# Create the callback
print_callback = PrintEveryNEpochs(n=10)

# Add the callback to model.fit
history = vqgan.fit(
    dataset,
    epochs=EPOCHS,
    callbacks=[print_callback]
)
average_loss = compute_average_reconstruction_loss(vqgan, dataset)
print(f"\nFinal Average Reconstruction Loss (L1): {average_loss:.6f}")

# If you want to plot the training history after completion
def plot_training_history(history):
    import matplotlib.pyplot as plt

    plt.figure(figsize=(12, 8))

    # Plot all metrics except for per-layer losses
    metrics_to_plot = [metric for metric in history.history.keys()
                      if not metric.startswith('encoder_') and
                         not metric.startswith('decoder_') and
                         not metric.startswith('discriminator_')]

    for metric in metrics_to_plot:
        plt.plot(history.history[metric], label=metric)

    plt.title('Training Metrics')
    plt.xlabel('Epoch')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

# Uncomment to plot training history
# plot_training_history(history)


# Add these right after your existing generate() and generate_alt() functions
def generate_improved(n=5, temperature=0.8):
    """Generate images with temperature control for smoother results"""
    # Sample from encoder output of real images instead of random sampling
    # This ensures we're in the learned manifold

    # Get a batch of real images from the dataset
    for batch in dataset.take(1):
        real_images = batch

    # Encode and quantize
    z_e = encoder(real_images)
    z_q = quantizer(z_e)

    # Create variations by adding controlled noise
    noise = tf.random.normal(shape=z_q.shape, stddev=temperature)
    z_variations = z_q + noise

    # Generate n new samples with the modified latents
    selected = z_variations[:n]
    samples = decoder(selected)

    return samples.numpy()

def denoise_images(images, strength=0.7):
    """Apply simple denoising to the generated images"""
    from scipy.ndimage import gaussian_filter

    processed = []
    for img in images:
        # Apply Gaussian blur for denoising
        denoised = gaussian_filter(img.squeeze(), sigma=strength)
        # Normalize back to [0,1] range
        denoised = (denoised - denoised.min()) / (denoised.max() - denoised.min())
        # Add channel dimension back if needed
        if len(denoised.shape) == 2:
            denoised = np.expand_dims(denoised, -1)
        processed.append(denoised)

    return np.array(processed)
# Out:
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 4.2777e-04 - g_loss: 0.9146 - recon_loss: 0.0018
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 4.2470e-04 - g_loss: 0.8727 - recon_loss: 0.0018
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.5154e-04 - g_loss: 0.8881 - recon_loss: 0.0019
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.7786e-04 - g_loss: 0.8708 - recon_loss: 0.0018
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 7.0781e-04 - g_loss: 0.8776 - recon_loss: 0.0018
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 4.2846e-04 - g_loss: 0.9750 - recon_loss: 0.0019
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.9579e-04 - g_loss: 0.8790 - recon_loss: 0.0019
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.2834e-04 - g_loss: 0.9002 - recon_loss: 0.0019
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.3220e-04 - g_loss: 0.9141 - recon_loss: 0.0018
# Epoch 10/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 4.8092e-04 - g_loss: 0.8665 - recon_loss: 0.0019
# === Results after epoch 10 ===
# d_loss: 0.0001
# g_loss: 0.9663
# recon_loss: 0.0011
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 4.3799e-04 - g_loss: 0.8783 - recon_loss: 0.0018
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - d_loss: 2.8488e-04 - g_loss: 0.8809 - recon_loss: 0.0018
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 3.9050e-04 - g_loss: 0.8860 - recon_loss: 0.0019
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.8323e-04 - g_loss: 0.8969 - recon_loss: 0.0018
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 3.0381e-04 - g_loss: 0.9452 - recon_loss: 0.0019
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.8539e-04 - g_loss: 0.8941 - recon_loss: 0.0019
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 5.3415e-04 - g_loss: 0.9483 - recon_loss: 0.0018
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 5.3955e-04 - g_loss: 0.8727 - recon_loss: 0.0018
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.6849e-04 - g_loss: 0.8919 - recon_loss: 0.0018
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 3.9298e-04 - g_loss: 0.9000 - recon_loss: 0.0018
# Epoch 20/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - d_loss: 2.9943e-04 - g_loss: 0.9073 - recon_loss: 0.0019
# === Results after epoch 20 ===
# d_loss: 0.0001
# g_loss: 0.9447
# recon_loss: 0.0017
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 2.7880e-04 - g_loss: 0.9117 - recon_loss: 0.0018
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 2.6515e-04 - g_loss: 0.9347 - recon_loss: 0.0020
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.5030e-04 - g_loss: 0.9105 - recon_loss: 0.0018
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 3.6190e-04 - g_loss: 0.9131 - recon_loss: 0.0018
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 3.0511e-04 - g_loss: 0.9619 - recon_loss: 0.0018
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 3.1441e-04 - g_loss: 0.8973 - recon_loss: 0.0018
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.4762e-04 - g_loss: 0.9128 - recon_loss: 0.0018
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.7044e-04 - g_loss: 0.9313 - recon_loss: 0.0018
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 2.2470e-04 - g_loss: 0.9329 - recon_loss: 0.0019
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.4011e-04 - g_loss: 0.9352 - recon_loss: 0.0019
# Epoch 30/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - d_loss: 2.4521e-04 - g_loss: 0.9307 - recon_loss: 0.0018
# === Results after epoch 30 ===
# d_loss: 0.0001
# g_loss: 0.9865
# recon_loss: 0.0037
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 2.3275e-04 - g_loss: 0.9372 - recon_loss: 0.0020
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.3601e-04 - g_loss: 0.9391 - recon_loss: 0.0019
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.0035e-04 - g_loss: 0.8966 - recon_loss: 0.0018
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.5359e-04 - g_loss: 0.9303 - recon_loss: 0.0019
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.2820e-04 - g_loss: 0.9177 - recon_loss: 0.0018
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.7579e-04 - g_loss: 0.9159 - recon_loss: 0.0019
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 4.4610e-04 - g_loss: 0.9402 - recon_loss: 0.0018
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.4641e-04 - g_loss: 1.0119 - recon_loss: 0.0019
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.2999e-04 - g_loss: 0.9346 - recon_loss: 0.0018
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.1081e-04 - g_loss: 0.9532 - recon_loss: 0.0019
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - d_loss: 2.2732e-04 - g_loss: 0.9250 - recon_loss: 0.0018
# === Results after epoch 40 ===
# d_loss: 0.0001
# g_loss: 0.9454
# recon_loss: 0.0018
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 2.2068e-04 - g_loss: 0.9262 - recon_loss: 0.0018
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - d_loss: 1.9629e-04 - g_loss: 0.9325 - recon_loss: 0.0019
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 2.5997e-04 - g_loss: 0.9776 - recon_loss: 0.0019
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.1621e-04 - g_loss: 0.9220 - recon_loss: 0.0019
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.0219e-04 - g_loss: 0.9627 - recon_loss: 0.0019
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.0233e-04 - g_loss: 0.9349 - recon_loss: 0.0018
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.0077e-04 - g_loss: 0.9309 - recon_loss: 0.0018
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.1406e-04 - g_loss: 0.9530 - recon_loss: 0.0018
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.6091e-04 - g_loss: 0.9705 - recon_loss: 0.0018
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.9685e-04 - g_loss: 0.9302 - recon_loss: 0.0019
# Epoch 50/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 3.3805e-04 - g_loss: 0.9166 - recon_loss: 0.0018
# === Results after epoch 50 ===
# d_loss: 0.0001
# g_loss: 0.9771
# recon_loss: 0.0021
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.0802e-04 - g_loss: 0.9237 - recon_loss: 0.0019
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.7215e-04 - g_loss: 0.9600 - recon_loss: 0.0018
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.3087e-04 - g_loss: 0.9794 - recon_loss: 0.0019
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.7091e-04 - g_loss: 0.9269 - recon_loss: 0.0018
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.1293e-04 - g_loss: 0.9203 - recon_loss: 0.0019
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.7186e-04 - g_loss: 0.9481 - recon_loss: 0.0019
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.8237e-04 - g_loss: 0.9481 - recon_loss: 0.0018
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.1599e-04 - g_loss: 0.9490 - recon_loss: 0.0019
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.4179e-04 - g_loss: 0.9419 - recon_loss: 0.0018
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.5145e-04 - g_loss: 0.9517 - recon_loss: 0.0018
# Epoch 60/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - d_loss: 1.7131e-04 - g_loss: 0.9468 - recon_loss: 0.0018
# === Results after epoch 60 ===
# d_loss: 0.0001
# g_loss: 0.9798
# recon_loss: 0.0020
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.6778e-04 - g_loss: 0.9507 - recon_loss: 0.0019
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.8449e-04 - g_loss: 0.9723 - recon_loss: 0.0018
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.1241e-04 - g_loss: 0.9637 - recon_loss: 0.0021
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6526e-04 - g_loss: 0.9543 - recon_loss: 0.0018
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.3103e-04 - g_loss: 0.9679 - recon_loss: 0.0018
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.0188e-04 - g_loss: 0.9395 - recon_loss: 0.0018
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 2.4863e-04 - g_loss: 0.9777 - recon_loss: 0.0019
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.0635e-04 - g_loss: 0.9442 - recon_loss: 0.0019
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.4114e-04 - g_loss: 0.9606 - recon_loss: 0.0019
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 1.6617e-04 - g_loss: 0.9906 - recon_loss: 0.0019
# Epoch 70/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 1.8875e-04 - g_loss: 0.9827 - recon_loss: 0.0018
# === Results after epoch 70 ===
# d_loss: 0.0004
# g_loss: 0.9910
# recon_loss: 0.0019
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.1761e-04 - g_loss: 0.9837 - recon_loss: 0.0019
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.5447e-04 - g_loss: 0.9455 - recon_loss: 0.0019
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 2.0564e-04 - g_loss: 0.9705 - recon_loss: 0.0019
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.5818e-04 - g_loss: 0.9958 - recon_loss: 0.0018
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.8854e-04 - g_loss: 0.9832 - recon_loss: 0.0018
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.3723e-04 - g_loss: 0.9564 - recon_loss: 0.0018
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.3003e-04 - g_loss: 0.9925 - recon_loss: 0.0018
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.3191e-04 - g_loss: 0.9944 - recon_loss: 0.0018
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.3109e-04 - g_loss: 0.9708 - recon_loss: 0.0018
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.2498e-04 - g_loss: 1.0007 - recon_loss: 0.0018
# Epoch 80/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 1.2797e-04 - g_loss: 0.9791 - recon_loss: 0.0019
# === Results after epoch 80 ===
# d_loss: 0.0002
# g_loss: 0.9653
# recon_loss: 0.0016
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.3086e-04 - g_loss: 0.9774 - recon_loss: 0.0018
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.2454e-04 - g_loss: 0.9894 - recon_loss: 0.0019
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.2572e-04 - g_loss: 0.9883 - recon_loss: 0.0019
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6371e-04 - g_loss: 1.0076 - recon_loss: 0.0019
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.1818e-04 - g_loss: 0.9674 - recon_loss: 0.0018
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6707e-04 - g_loss: 0.9758 - recon_loss: 0.0018
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.9769e-04 - g_loss: 1.0102 - recon_loss: 0.0019
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.5839e-04 - g_loss: 0.9756 - recon_loss: 0.0018
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - d_loss: 1.1436e-04 - g_loss: 1.0163 - recon_loss: 0.0019
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.2555e-04 - g_loss: 0.9922 - recon_loss: 0.0019
# Epoch 90/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 1.1467e-04 - g_loss: 0.9756 - recon_loss: 0.0018
# === Results after epoch 90 ===
# d_loss: 0.0001
# g_loss: 0.9890
# recon_loss: 0.0019
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.1499e-04 - g_loss: 0.9772 - recon_loss: 0.0019
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.2514e-04 - g_loss: 0.9925 - recon_loss: 0.0018
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.0254e-04 - g_loss: 1.0044 - recon_loss: 0.0018
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6758e-04 - g_loss: 0.9718 - recon_loss: 0.0019
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.7624e-04 - g_loss: 1.0258 - recon_loss: 0.0020
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.9601e-04 - g_loss: 1.0036 - recon_loss: 0.0018
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.3379e-04 - g_loss: 0.9878 - recon_loss: 0.0019
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - d_loss: 1.5309e-04 - g_loss: 1.0269 - recon_loss: 0.0018
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 1.1535e-04 - g_loss: 1.0023 - recon_loss: 0.0018
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 1.0832e-04 - g_loss: 0.9830 - recon_loss: 0.0018
# Epoch 100/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 1.2738e-04 - g_loss: 0.9846 - recon_loss: 0.0019
# === Results after epoch 100 ===
# d_loss: 0.0001
# g_loss: 1.0227
# recon_loss: 0.0009
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.2617e-04 - g_loss: 0.9891 - recon_loss: 0.0018
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.4194e-04 - g_loss: 0.9897 - recon_loss: 0.0018
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.2426e-04 - g_loss: 1.0499 - recon_loss: 0.0018
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 1.0037e-04 - g_loss: 0.9986 - recon_loss: 0.0019
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 2.0430e-04 - g_loss: 0.9871 - recon_loss: 0.0019
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.3190e-04 - g_loss: 1.0477 - recon_loss: 0.0018
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6013e-04 - g_loss: 1.0169 - recon_loss: 0.0019
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 9.7620e-05 - g_loss: 0.9840 - recon_loss: 0.0019
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.1164e-04 - g_loss: 1.0177 - recon_loss: 0.0019
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 9.0824e-05 - g_loss: 1.0159 - recon_loss: 0.0018
# Epoch 110/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 1.1328e-04 - g_loss: 1.0477 - recon_loss: 0.0019
# === Results after epoch 110 ===
# d_loss: 0.0001
# g_loss: 0.9208
# recon_loss: 0.0017
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.1409e-04 - g_loss: 1.0327 - recon_loss: 0.0018
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.4725e-05 - g_loss: 1.0284 - recon_loss: 0.0018
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.1294e-04 - g_loss: 1.0347 - recon_loss: 0.0019
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.6572e-04 - g_loss: 1.0603 - recon_loss: 0.0019
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.4951e-04 - g_loss: 0.9914 - recon_loss: 0.0018
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.6295e-04 - g_loss: 1.0588 - recon_loss: 0.0019
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.3433e-04 - g_loss: 1.0084 - recon_loss: 0.0019
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.5766e-05 - g_loss: 1.0323 - recon_loss: 0.0019
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.2029e-04 - g_loss: 1.0365 - recon_loss: 0.0018
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.4742e-04 - g_loss: 1.0103 - recon_loss: 0.0018
# Epoch 120/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 9.5641e-05 - g_loss: 1.0193 - recon_loss: 0.0019
# === Results after epoch 120 ===
# d_loss: 0.0000
# g_loss: 1.1417
# recon_loss: 0.0017
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.6903e-05 - g_loss: 1.0337 - recon_loss: 0.0018
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 1.4489e-04 - g_loss: 1.0374 - recon_loss: 0.0018
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.8387e-05 - g_loss: 1.0511 - recon_loss: 0.0019
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.9096e-05 - g_loss: 1.0317 - recon_loss: 0.0018
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.3008e-05 - g_loss: 1.0290 - recon_loss: 0.0019
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.1398e-04 - g_loss: 1.0548 - recon_loss: 0.0018
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - d_loss: 1.0161e-04 - g_loss: 1.0112 - recon_loss: 0.0019
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 8.2827e-05 - g_loss: 1.0156 - recon_loss: 0.0018
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - d_loss: 9.8395e-05 - g_loss: 1.0378 - recon_loss: 0.0018
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.1630e-05 - g_loss: 1.0451 - recon_loss: 0.0019
# Epoch 130/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 8.2096e-05 - g_loss: 1.0280 - recon_loss: 0.0019
# === Results after epoch 130 ===
# d_loss: 0.0000
# g_loss: 1.0533
# recon_loss: 0.0014
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.7096e-05 - g_loss: 1.0310 - recon_loss: 0.0018
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 7.5512e-05 - g_loss: 1.0739 - recon_loss: 0.0019
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.4995e-05 - g_loss: 1.0306 - recon_loss: 0.0019
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.3888e-05 - g_loss: 1.0682 - recon_loss: 0.0020
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.9048e-05 - g_loss: 1.0569 - recon_loss: 0.0018
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.6042e-05 - g_loss: 1.0641 - recon_loss: 0.0018
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.8715e-05 - g_loss: 1.0448 - recon_loss: 0.0018
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 7.6638e-05 - g_loss: 1.0490 - recon_loss: 0.0019
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 8.0189e-05 - g_loss: 1.0481 - recon_loss: 0.0019
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 8.1223e-05 - g_loss: 1.0431 - recon_loss: 0.0018
# Epoch 140/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 7.8017e-05 - g_loss: 1.0292 - recon_loss: 0.0018
# === Results after epoch 140 ===
# d_loss: 0.0000
# g_loss: 1.1217
# recon_loss: 0.0023
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.1156e-05 - g_loss: 1.0400 - recon_loss: 0.0019
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.5279e-05 - g_loss: 1.0645 - recon_loss: 0.0018
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.7448e-05 - g_loss: 1.0640 - recon_loss: 0.0019
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.6631e-05 - g_loss: 1.0397 - recon_loss: 0.0018
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.9847e-05 - g_loss: 1.0804 - recon_loss: 0.0019
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.4507e-05 - g_loss: 1.0336 - recon_loss: 0.0018
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 9.6591e-05 - g_loss: 1.0359 - recon_loss: 0.0019
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 7.8032e-05 - g_loss: 1.0666 - recon_loss: 0.0019
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.8848e-05 - g_loss: 1.0480 - recon_loss: 0.0018
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 7.2851e-05 - g_loss: 1.0665 - recon_loss: 0.0018
# Epoch 150/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - d_loss: 7.0035e-05 - g_loss: 1.0405 - recon_loss: 0.0018
# === Results after epoch 150 ===
# d_loss: 0.0001
# g_loss: 1.0534
# recon_loss: 0.0020
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.8942e-05 - g_loss: 1.0420 - recon_loss: 0.0019
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.1387e-05 - g_loss: 1.0935 - recon_loss: 0.0018
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 1.0967e-04 - g_loss: 1.0577 - recon_loss: 0.0018
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 8.1185e-05 - g_loss: 1.0249 - recon_loss: 0.0018
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - d_loss: 6.1766e-05 - g_loss: 1.0565 - recon_loss: 0.0018
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - d_loss: 6.5559e-05 - g_loss: 1.0908 - recon_loss: 0.0018
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.1770e-05 - g_loss: 1.0483 - recon_loss: 0.0019
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 5.3383e-05 - g_loss: 1.0725 - recon_loss: 0.0018
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 5.4384e-05 - g_loss: 1.0857 - recon_loss: 0.0019
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 6.8663e-05 - g_loss: 1.0648 - recon_loss: 0.0018
# Epoch 160/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 5.2095e-05 - g_loss: 1.0697 - recon_loss: 0.0019
# === Results after epoch 160 ===
# d_loss: 0.0005
# g_loss: 1.1293
# recon_loss: 0.0016
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 1.0098e-04 - g_loss: 1.0767 - recon_loss: 0.0018
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.8953e-05 - g_loss: 1.0327 - recon_loss: 0.0020
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.5917e-05 - g_loss: 1.1099 - recon_loss: 0.0019
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 4.7472e-05 - g_loss: 1.0602 - recon_loss: 0.0018
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 9.6832e-05 - g_loss: 1.0441 - recon_loss: 0.0019
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 7.6824e-05 - g_loss: 1.1400 - recon_loss: 0.0018
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.1312e-05 - g_loss: 1.0479 - recon_loss: 0.0019
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.6817e-05 - g_loss: 1.0713 - recon_loss: 0.0019
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 5.1151e-05 - g_loss: 1.0984 - recon_loss: 0.0019
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.7184e-05 - g_loss: 1.0733 - recon_loss: 0.0019
# Epoch 170/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 5.6068e-05 - g_loss: 1.0976 - recon_loss: 0.0019
# === Results after epoch 170 ===
# d_loss: 0.0000
# g_loss: 1.0674
# recon_loss: 0.0010
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.4788e-05 - g_loss: 1.0941 - recon_loss: 0.0018
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.5421e-05 - g_loss: 1.0844 - recon_loss: 0.0018
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 5.1826e-05 - g_loss: 1.0694 - recon_loss: 0.0019
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.8606e-05 - g_loss: 1.0896 - recon_loss: 0.0018
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.7461e-05 - g_loss: 1.0749 - recon_loss: 0.0019
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 5.6017e-05 - g_loss: 1.0661 - recon_loss: 0.0019
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.4566e-05 - g_loss: 1.1663 - recon_loss: 0.0018
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.9465e-05 - g_loss: 1.0646 - recon_loss: 0.0020
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.4340e-05 - g_loss: 1.1288 - recon_loss: 0.0018
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 4.8379e-05 - g_loss: 1.0873 - recon_loss: 0.0018
# Epoch 180/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 3.1626e-05 - g_loss: 1.1043 - recon_loss: 0.0018
# === Results after epoch 180 ===
# d_loss: 0.0004
# g_loss: 1.1599
# recon_loss: 0.0027
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 7.8470e-05 - g_loss: 1.1109 - recon_loss: 0.0019
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.2219e-05 - g_loss: 1.0521 - recon_loss: 0.0019
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - d_loss: 5.7385e-05 - g_loss: 1.1868 - recon_loss: 0.0019
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - d_loss: 6.3902e-05 - g_loss: 1.0562 - recon_loss: 0.0018
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 4.2439e-05 - g_loss: 1.1011 - recon_loss: 0.0018
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.3494e-05 - g_loss: 1.1029 - recon_loss: 0.0019
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.8470e-05 - g_loss: 1.0853 - recon_loss: 0.0018
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.8989e-05 - g_loss: 1.1241 - recon_loss: 0.0019
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.5023e-05 - g_loss: 1.1162 - recon_loss: 0.0018
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 6.8911e-05 - g_loss: 1.0632 - recon_loss: 0.0018
# Epoch 190/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 4.6610e-05 - g_loss: 1.1428 - recon_loss: 0.0018
# === Results after epoch 190 ===
# d_loss: 0.0000
# g_loss: 1.0757
# recon_loss: 0.0021
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - d_loss: 4.4382e-05 - g_loss: 1.1349 - recon_loss: 0.0019
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.7946e-05 - g_loss: 1.0928 - recon_loss: 0.0018
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.1053e-05 - g_loss: 1.1304 - recon_loss: 0.0020
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.9441e-05 - g_loss: 1.0899 - recon_loss: 0.0019
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 5.3261e-05 - g_loss: 1.1345 - recon_loss: 0.0019
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.8406e-05 - g_loss: 1.0962 - recon_loss: 0.0018
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 4.2475e-05 - g_loss: 1.1043 - recon_loss: 0.0019
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - d_loss: 3.3238e-05 - g_loss: 1.1223 - recon_loss: 0.0018
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.6595e-05 - g_loss: 1.1089 - recon_loss: 0.0019
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 3.8597e-05 - g_loss: 1.1185 - recon_loss: 0.0018
# Epoch 200/200
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - d_loss: 2.8344e-05 - g_loss: 1.1217 - recon_loss: 0.0018
# === Results after epoch 200 ===
# d_loss: 0.0003
# g_loss: 1.1842
# recon_loss: 0.0022
# ==============================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - d_loss: 6.3611e-05 - g_loss: 1.1291 - recon_loss: 0.0019
# Average Reconstruction Loss (L1): 0.001851
# 0.001851163625717163
#
# Final Average Reconstruction Loss (L1): 0.001851

# %%
# === Cell 12: Generate new samples (Fixed) ===
def generate(n=5):
    # Print dimensions of quantizer embeddings to verify
    print(f"Quantizer embeddings shape: {quantizer.embeddings.shape}")

    # Sample random indices
    idx = tf.random.uniform((n, IMG_SIZE//4, IMG_SIZE//4), maxval=NUM_EMBEDDINGS, dtype=tf.int32)
    one_hot = tf.one_hot(idx, NUM_EMBEDDINGS)  # [n, h, w, K]
    print(f"One-hot shape: {one_hot.shape}")

    # Use matmul instead of embedding_lookup to get the correct dimensions
    # The embeddings are stored as [LATENT_DIM, NUM_EMBEDDINGS]
    # We need to reshape and transpose for the matmul operation
    flat_one_hot = tf.reshape(one_hot, [-1, NUM_EMBEDDINGS])  # [n*h*w, K]
    flat_quantized = tf.matmul(flat_one_hot, tf.transpose(quantizer.embeddings))  # [n*h*w, D]

    # Reshape back to the expected format [n, h, w, D]
    h = w = IMG_SIZE // 4
    quantized = tf.reshape(flat_quantized, [n, h, w, LATENT_DIM])
    print(f"Final quantized shape: {quantized.shape}")

    # Pass to decoder
    images = decoder(quantized)
    return images.numpy()

# Alternative implementation if the above doesn't work
def generate_alt(n=5):
    # Create random latent vectors directly in the shape decoder expects
    h, w = IMG_SIZE//4, IMG_SIZE//4

    # Important: Use LATENT_DIM (256) not quantizer.embeddings.shape[1] (512)
    # The error shows decoder expects (None, 16, 16, 256)
    print(f"Using LATENT_DIM: {LATENT_DIM}")

    # Create random latent vectors with the correct shape
    random_latents = tf.random.normal((n, h, w, LATENT_DIM))
    print(f"Random latents shape: {random_latents.shape}")

    # Generate images from these latents
    images = decoder(random_latents)
    return images.numpy()

# Try the first method
# Replace the existing try/except block with this
try:
    print("Generating with improved method...")
    imgs = generate_improved(10, temperature=0.5)
except Exception as e:
    print(f"Improved method failed: {e}")
    print("Trying alternative method...")
    try:
        imgs = generate(10)  # Try the original method first
    except Exception as e:
        print(f"Original method failed: {e}")
        print("Falling back to simplest method...")
        imgs = generate_alt(10)

# Optional: Apply denoising
try:
    imgs = denoise_images(imgs, strength=0.5)
    print("Applied denoising filter")
except ImportError:
    print("Scipy not available for denoising")
# Display the generated images
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, len(imgs), figsize=(15,3))
for i, im in enumerate(imgs):
    # For color images
    if im.shape[-1] == 3:
        axs[i].imshow(im)
    # For grayscale
    else:
        axs[i].imshow(im.squeeze(), cmap="gray")
    axs[i].axis("off")
plt.show()
# Out:
# Generating with improved method...
# Applied denoising filter

# %%
def compute_average_reconstruction_loss(model, dataset):
    total_loss = 0.0
    num_samples = 0

    for batch in dataset:
        recon = model.decoder(model.quantizer(model.encoder(batch)))
        loss = tf.reduce_sum(tf.abs(recon - batch))  # L1 loss
        total_loss += loss.numpy()
        num_samples += tf.size(batch).numpy()

    avg_loss = total_loss / num_samples
    return avg_loss
